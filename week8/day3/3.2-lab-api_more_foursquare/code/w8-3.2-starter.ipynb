# %% [markdown]
# # Setting up Foursquare data for analysis

# %% [markdown]
# > Note: This will be a very open ended lab, since everyone may end up using different geographies and starting seed geographies. Be prepared to walk around and hand-hold some people, I've tested this out on several locales around me and it works, for most, but if you don't have a good starting seed location, the procedure may not scrape well.
#
# Today's lab is going to get your hands dirty with respect to the Foursquare API. We're also going to build a simple crawler/scraper that will go through the JSON hierarchy, extract the data we want, and deposit them into a Pandas table so we can do simple analysis.
#
# Just in case you're unfamiliar with this concept, please refer to the Wikipedia page (it's actually pretty good): https://en.wikipedia.org/wiki/Web_scraping, and maybe spend a few moments discussing the concepts and how it could help you in the future as a data scientist to have this "hackish" skill.

# %% [markdown]
# Setup your access token to foursquare

# %%
# Solutions

import foursquare
import json
import pandas as pd
import unicodedata

CLIENT_ID = 'Z4PSJN0G0Q44QX1SL0SSWI3EXA0KWG0POKGKHFY0J35EIIQE'
CLIENT_SECRET = 'EHRZQ4XSZKFEQIG03D1AS0BFFR3LE00GSBHOJUNOOKELUDHV'
client = foursquare.Foursquare(client_id=CLIENT_ID,client_secret=CLIENT_SECRET)

# %% [markdown]
# Use a foursquare python library method to search for suitable venues around a city near you. Print the associated JSON output in a nice way with appropriate spacing and indentation

# %%
la_bresse = client.venues.search(params={'ll': ' 47.9883673828,6.8417737928'})

# %%
# Solution
client.venues.search(params={'query': 'coffee','ll': ' 47.9883673828,6.8417737928'})
# Out:
# {u'venues': [{u'allowMenuUrlEdit': True,
#    u'beenHere': {u'lastCheckinExpiredAt': 0,
#     u'marked': False,
#     u'unconfirmedCount': 0},
#    u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d14e941735',
#      u'name': u'American Restaurant',
#      u'pluralName': u'American Restaurants',
#      u'primary': True,
#      u'shortName': u'American'}],
#    u'contact': {u'formattedPhone': u'+33 3 29 34 20 15',
#     u'phone': u'+33329342015'},
#    u'hasPerk': False,
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'579107e5498e4506bbd70cba',
#    u'location': {u'address': u'48 Route de Jeuxey',
#     u'cc': u'FR',
#     u'city': u'\ufffd\ufffdpinal',
#     u'country': u'France',
#     u'distance': 36427,
#     u'formattedAddress': [u'48 Route de Jeuxey',
#      u'\ufffd\ufffdpinal',
#      u'France'],
#     u'labeledLatLngs': [{u'label': u'display',
#       u'lat': 48.19472,
#       u'lng': 6.461544}],
#     u'lat': 48.19472,
#     u'lng': 6.461544},
#    u'name': u'Memphis Coffee',
#    u'referralId': u'v-1480504489',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 0, u'tipCount': 0, u'usersCount': 0},
#    u'storeId': u'MC23',
#    u'url': u'http://www.memphis-coffee.com/memphis-coffee-%C3%A9pinal',
#    u'venueChains': [],
#    u'verified': True},
#   {u'allowMenuUrlEdit': True,
#    u'beenHere': {u'lastCheckinExpiredAt': 0,
#     u'marked': False,
#     u'unconfirmedCount': 0},
#    u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d14e941735',
#      u'name': u'American Restaurant',
#      u'pluralName': u'American Restaurants',
#      u'primary': True,
#      u'shortName': u'American'}],
#    u'contact': {u'formattedPhone': u'+33 3 29 34 20 15',
#     u'phone': u'+33329342015'},
#    u'hasPerk': False,
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'57a2119ccd10cf0325fcb5a8',
#    u'location': {u'address': u'48 Route de Jeuxey',
#     u'cc': u'FR',
#     u'city': u'\xc9pinal',
#     u'country': u'France',
#     u'distance': 36427,
#     u'formattedAddress': [u'48 Route de Jeuxey', u'\xc9pinal', u'France'],
#     u'labeledLatLngs': [{u'label': u'display',
#       u'lat': 48.19472,
#       u'lng': 6.461544}],
#     u'lat': 48.19472,
#     u'lng': 6.461544,
#     u'state': u'Lorraine'},
#    u'name': u'Memphis Coffee \xc9pinal',
#    u'referralId': u'v-1480504489',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 0, u'tipCount': 0, u'usersCount': 0},
#    u'storeId': u'MC23',
#    u'url': u'http://www.memphis-coffee.com/memphis-coffee-%C3%A9pinal',
#    u'venueChains': [],
#    u'verified': True}]}

# %% [markdown]
# Wow... that should look like a total mess to you. Read the following docs: https://docs.python.org/2/library/json.html, and read the part about pretty printing. Once you think you've understood the method, deploy it here and see the world a difference a bit of spacing and indenting makes!

# %%
import json
print(json.dumps(la_bresse,indent=4))
# Out:
# {
#     "confident": true,
#     "venues": [
#         {
#             "verified": false,
#             "name": "Bar Lounge La Grange",
#             "referralId": "v-1480504550",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 52,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.9879315472925,
#                         "lng": 6.842047897106891,
#                         "label": "display"
#                     }
#                 ],
#                 "city": "Cornimont",
#                 "cc": "FR",
#                 "country": "France",
#                 "postalCode": "88310",
#                 "state": "Lorraine",
#                 "formattedAddress": [
#                     "28 Route De Lansauchamps",
#                     "88310 Cornimont",
#                     "France"
#                 ],
#                 "address": "28 Route De Lansauchamps",
#                 "lat": 47.9879315472925,
#                 "lng": 6.842047897106891
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 1,
#                 "checkinsCount": 7,
#                 "usersCount": 7
#             },
#             "id": "5144e8e8e4b0df0d717aaf71",
#             "categories": [
#                 {
#                     "pluralName": "Lounges",
#                     "primary": true,
#                     "name": "Lounge",
#                     "shortName": "Lounge",
#                     "id": "4bf58dd8d48988d121941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "referralId": "v-1480504550",
#             "verified": false,
#             "name": "La Bresse",
#             "venueRatingBlacklisted": true,
#             "url": "http://www.labresse.net",
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "venueChains": [],
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 3495,
#                 "cc": "FR",
#                 "country": "France",
#                 "postalCode": "88250",
#                 "state": "Lorraine",
#                 "formattedAddress": [
#                     "88250",
#                     "France"
#                 ],
#                 "lat": 48.004833543828546,
#                 "lng": 6.88173499186469
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 1001,
#                 "usersCount": 693
#             },
#             "id": "4b8aa547f964a5204a7732e3",
#             "categories": [
#                 {
#                     "pluralName": "Cities",
#                     "primary": true,
#                     "name": "City",
#                     "shortName": "City",
#                     "id": "50aa9e094b90af0d42d5de0d",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Ferme des Vieux Sapins",
#             "referralId": "v-1480504550",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 832,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.995826,
#                         "lng": 6.84089,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "FR",
#                 "country": "France",
#                 "formattedAddress": [
#                     "France"
#                 ],
#                 "lat": 47.995826,
#                 "lng": 6.84089
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 1,
#                 "checkinsCount": 14,
#                 "usersCount": 5
#             },
#             "id": "54c3d4e7498efefa00ef2462",
#             "categories": [
#                 {
#                     "pluralName": "Bed & Breakfasts",
#                     "primary": true,
#                     "name": "Bed & Breakfast",
#                     "shortName": "B & B",
#                     "id": "4bf58dd8d48988d1f8931735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/bedandbreakfast_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Les Chalets des Chatelmin\u00e9s",
#             "referralId": "v-1480504550",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 1016,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.99301383555673,
#                         "lng": 6.853527008827831,
#                         "label": "display"
#                     }
#                 ],
#                 "city": "La Bresse",
#                 "cc": "FR",
#                 "country": "France",
#                 "state": "Lorraine",
#                 "formattedAddress": [
#                     "Route de Cornimont 41",
#                     "La Bresse",
#                     "France"
#                 ],
#                 "address": "Route de Cornimont 41",
#                 "lat": 47.99301383555673,
#                 "lng": 6.853527008827831
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 20,
#                 "usersCount": 4
#             },
#             "id": "56fbfa8a498e17f33c1a6ae0",
#             "categories": [
#                 {
#                     "pluralName": "Vacation Rentals",
#                     "primary": true,
#                     "name": "Vacation Rental",
#                     "shortName": "Vacation Rental",
#                     "id": "56aa371be4b08b9a8d5734e1",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/hostel_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Col d'Oderen",
#             "referralId": "v-1480504550",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 5217,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 48.002198300691305,
#                         "lng": 6.90869485930805,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "FR",
#                 "country": "France",
#                 "formattedAddress": [
#                     "France"
#                 ],
#                 "lat": 48.002198300691305,
#                 "lng": 6.90869485930805
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 9,
#                 "usersCount": 7
#             },
#             "id": "4fabd566e4b0c3c98b38a34b",
#             "categories": [
#                 {
#                     "pluralName": "Mountains",
#                     "primary": true,
#                     "name": "Mountain",
#                     "shortName": "Mountain",
#                     "id": "4eb1d4d54b900d56c88a45fc",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/mountain_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Col Du Brabant",
#             "referralId": "v-1480504550",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 2064,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.987278,
#                         "lng": 6.8694415,
#                         "label": "display"
#                     }
#                 ],
#                 "city": "La Bresse",
#                 "cc": "FR",
#                 "country": "France",
#                 "postalCode": "88250",
#                 "state": "Lorraine",
#                 "formattedAddress": [
#                     "88250 La Bresse",
#                     "France"
#                 ],
#                 "lat": 47.987278,
#                 "lng": 6.8694415
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 2,
#                 "usersCount": 2
#             },
#             "id": "57c19a5bcd10e5cf81c11edc",
#             "categories": [
#                 {
#                     "pluralName": "Mountains",
#                     "primary": true,
#                     "name": "Mountain",
#                     "shortName": "Mountain",
#                     "id": "4eb1d4d54b900d56c88a45fc",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/mountain_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Collet Mansuy",
#             "referralId": "v-1480504550",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 4126,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.988663,
#                         "lng": 6.8971624,
#                         "label": "display"
#                     }
#                 ],
#                 "city": "La Bresse",
#                 "cc": "FR",
#                 "country": "France",
#                 "postalCode": "88250",
#                 "state": "Lorraine",
#                 "formattedAddress": [
#                     "88250 La Bresse",
#                     "France"
#                 ],
#                 "lat": 47.988663,
#                 "lng": 6.8971624
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 3,
#                 "usersCount": 3
#             },
#             "id": "57c6e896498ecd24942427df",
#             "categories": [
#                 {
#                     "pluralName": "Mountains",
#                     "primary": true,
#                     "name": "Mountain",
#                     "shortName": "Mountain",
#                     "id": "4eb1d4d54b900d56c88a45fc",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/mountain_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Bol d'air",
#             "referralId": "v-1480504550",
#             "url": "http://www.bol-d-air.fr",
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "venueChains": [],
#             "contact": {
#                 "facebookName": "Bol d'Air",
#                 "twitter": "bol_dair",
#                 "phone": "+33329256262",
#                 "facebook": "107160597501",
#                 "formattedPhone": "+33 3 29 25 62 62",
#                 "facebookUsername": "boldair"
#             },
#             "hasPerk": false,
#             "location": {
#                 "distance": 5181,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 48.002563844101495,
#                         "lng": 6.908016049679116,
#                         "label": "display"
#                     }
#                 ],
#                 "city": "La Bresse",
#                 "cc": "FR",
#                 "country": "France",
#                 "postalCode": "88250",
#                 "state": "Lorraine",
#                 "formattedAddress": [
#                     "76 rue du Hohneck",
#                     "88250 La Bresse",
#                     "France"
#                 ],
#                 "address": "76 rue du Hohneck",
#                 "lat": 48.002563844101495,
#                 "lng": 6.908016049679116
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 2,
#                 "checkinsCount": 116,
#                 "usersCount": 100
#             },
#             "id": "4b51036ff964a520953d27e3",
#             "categories": [
#                 {
#                     "pluralName": "Theme Park Rides/Attractions",
#                     "primary": true,
#                     "name": "Theme Park Ride / Attraction",
#                     "shortName": "Theme Park",
#                     "id": "5109983191d435c0d71c2bb1",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Le Den's",
#             "referralId": "v-1480504550",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 2995,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 48.00370395183563,
#                         "lng": 6.874818205833435,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "FR",
#                 "country": "France",
#                 "formattedAddress": [
#                     "France"
#                 ],
#                 "lat": 48.00370395183563,
#                 "lng": 6.874818205833435
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 2,
#                 "checkinsCount": 80,
#                 "usersCount": 68
#             },
#             "id": "4c4f638a63690f471c9f5d46",
#             "categories": [
#                 {
#                     "pluralName": "Bars",
#                     "primary": true,
#                     "name": "Bar",
#                     "shortName": "Bar",
#                     "id": "4bf58dd8d48988d116941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/pub_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "referralId": "v-1480504550",
#             "verified": false,
#             "name": "Ventron",
#             "venueRatingBlacklisted": true,
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 5750,
#                 "cc": "FR",
#                 "country": "France",
#                 "state": "Lorraine",
#                 "formattedAddress": [
#                     "France"
#                 ],
#                 "lat": 47.940578042371605,
#                 "lng": 6.871053198671209
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 29,
#                 "usersCount": 23
#             },
#             "id": "53e9f632498e9bee1737b5c4",
#             "categories": [
#                 {
#                     "pluralName": "Cities",
#                     "primary": true,
#                     "name": "City",
#                     "shortName": "City",
#                     "id": "50aa9e094b90af0d42d5de0d",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Les D\u00e9lices de la Bresse Pinot",
#             "referralId": "v-1480504550",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 3512,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 48.007012,
#                         "lng": 6.879813,
#                         "label": "display"
#                     }
#                 ],
#                 "city": "La Bresse",
#                 "cc": "FR",
#                 "country": "France",
#                 "state": "Lorraine",
#                 "formattedAddress": [
#                     "La Bresse",
#                     "France"
#                 ],
#                 "lat": 48.007012,
#                 "lng": 6.879813
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 1,
#                 "usersCount": 1
#             },
#             "id": "5804a4d6d67c73d742a7eb07",
#             "categories": [
#                 {
#                     "pluralName": "Bakeries",
#                     "primary": true,
#                     "name": "Bakery",
#                     "shortName": "Bakery",
#                     "id": "4bf58dd8d48988d16a941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/bakery_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "referralId": "v-1480504550",
#             "verified": false,
#             "name": "Lac des Corbeaux",
#             "venueRatingBlacklisted": true,
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 4761,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.993276165085646,
#                         "lng": 6.905269659432475,
#                         "label": "display"
#                     }
#                 ],
#                 "city": "La Bresse",
#                 "cc": "FR",
#                 "country": "France",
#                 "state": "Lorraine",
#                 "formattedAddress": [
#                     "La Bresse",
#                     "France"
#                 ],
#                 "lat": 47.993276165085646,
#                 "lng": 6.905269659432475
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 1,
#                 "checkinsCount": 51,
#                 "usersCount": 47
#             },
#             "id": "4c234eb67e85c9289f4bbd21",
#             "categories": [
#                 {
#                     "pluralName": "Lakes",
#                     "primary": true,
#                     "name": "Lake",
#                     "shortName": "Lake",
#                     "id": "4bf58dd8d48988d161941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/lake_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Super U",
#             "referralId": "v-1480504550",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 3533,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 48.00709084521954,
#                         "lng": 6.880078978330875,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "FR",
#                 "country": "France",
#                 "formattedAddress": [
#                     "France"
#                 ],
#                 "lat": 48.00709084521954,
#                 "lng": 6.880078978330875
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 81,
#                 "usersCount": 64
#             },
#             "id": "4e3be98245dd68e32723a16c",
#             "categories": [
#                 {
#                     "pluralName": "Grocery Stores",
#                     "primary": true,
#                     "name": "Grocery Store",
#                     "shortName": "Grocery Store",
#                     "id": "4bf58dd8d48988d118951735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Piquante Pierre",
#             "referralId": "v-1480504550",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 3552,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.994451,
#                         "lng": 6.794966,
#                         "label": "display"
#                     }
#                 ],
#                 "city": "La Bresse",
#                 "cc": "FR",
#                 "country": "France",
#                 "state": "Lorraine",
#                 "formattedAddress": [
#                     "La Bresse",
#                     "France"
#                 ],
#                 "lat": 47.994451,
#                 "lng": 6.794966
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 4,
#                 "usersCount": 4
#             },
#             "id": "4f23d555e4b05d3ba0a75c4e",
#             "categories": [
#                 {
#                     "pluralName": "Mountains",
#                     "primary": true,
#                     "name": "Mountain",
#                     "shortName": "Mountain",
#                     "id": "4eb1d4d54b900d56c88a45fc",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/mountain_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "office du tourisme la bresse",
#             "referralId": "v-1480504550",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 3128,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 48.00485610961914,
#                         "lng": 6.875781536102295,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "FR",
#                 "country": "France",
#                 "formattedAddress": [
#                     "France"
#                 ],
#                 "lat": 48.00485610961914,
#                 "lng": 6.875781536102295
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 5,
#                 "usersCount": 5
#             },
#             "id": "50192c2de4b041fa621b88b4",
#             "categories": [
#                 {
#                     "pluralName": "Tourist Information Centers",
#                     "primary": true,
#                     "name": "Tourist Information Center",
#                     "shortName": "Tourist Information",
#                     "id": "4f4530164b9074f6e4fb00ff",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/touristinformation_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Col De La Croix Des Moinats",
#             "referralId": "v-1480504550",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 1853,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.987503,
#                         "lng": 6.816926,
#                         "label": "display"
#                     }
#                 ],
#                 "city": "Cornimont",
#                 "cc": "FR",
#                 "country": "France",
#                 "state": "Lorraine",
#                 "formattedAddress": [
#                     "Cornimont",
#                     "France"
#                 ],
#                 "lat": 47.987503,
#                 "lng": 6.816926
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 8,
#                 "usersCount": 6
#             },
#             "id": "520cda4b498e8b023f0e1380",
#             "categories": [
#                 {
#                     "pluralName": "Mountains",
#                     "primary": true,
#                     "name": "Mountain",
#                     "shortName": "Mountain",
#                     "id": "4eb1d4d54b900d56c88a45fc",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/mountain_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Vosges en Marche",
#             "referralId": "v-1480504550",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 3570,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.987184,
#                         "lng": 6.793885,
#                         "label": "display"
#                     }
#                 ],
#                 "city": "Basse-sur-le-Rupt",
#                 "cc": "FR",
#                 "country": "France",
#                 "postalCode": "88120",
#                 "state": "Lorraine",
#                 "formattedAddress": [
#                     "Presles",
#                     "88120 Basse-sur-le-Rupt",
#                     "France"
#                 ],
#                 "address": "Presles",
#                 "lat": 47.987184,
#                 "lng": 6.793885
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 11,
#                 "usersCount": 2
#             },
#             "id": "4ebd4bf282317d5cdb051da6",
#             "categories": [
#                 {
#                     "pluralName": "Hostels",
#                     "primary": true,
#                     "name": "Hostel",
#                     "shortName": "Hostel",
#                     "id": "4bf58dd8d48988d1ee931735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/hostel_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "honneck",
#             "referralId": "v-1480504551",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 5815,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.99932742356907,
#                         "lng": 6.918098985171378,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "FR",
#                 "country": "France",
#                 "formattedAddress": [
#                     "France"
#                 ],
#                 "lat": 47.99932742356907,
#                 "lng": 6.918098985171378
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 20,
#                 "usersCount": 16
#             },
#             "id": "4ff29eebe4b007be0a1a84eb",
#             "categories": [
#                 {
#                     "pluralName": "Mountains",
#                     "primary": true,
#                     "name": "Mountain",
#                     "shortName": "Mountain",
#                     "id": "4eb1d4d54b900d56c88a45fc",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/mountain_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "G\u00eete Pima",
#             "referralId": "v-1480504551",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 3930,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 48.01407,
#                         "lng": 6.877945,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "FR",
#                 "country": "France",
#                 "formattedAddress": [
#                     "France"
#                 ],
#                 "lat": 48.01407,
#                 "lng": 6.877945
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 1,
#                 "checkinsCount": 3,
#                 "usersCount": 1
#             },
#             "id": "5810906e38fa3355dcff9e50",
#             "categories": [
#                 {
#                     "pluralName": "Vacation Rentals",
#                     "primary": true,
#                     "name": "Vacation Rental",
#                     "shortName": "Vacation Rental",
#                     "id": "56aa371be4b08b9a8d5734e1",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/hostel_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "l'auberge du brabant",
#             "referralId": "v-1480504551",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 2088,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.988086,
#                         "lng": 6.869805,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "FR",
#                 "country": "France",
#                 "formattedAddress": [
#                     "France"
#                 ],
#                 "lat": 47.988086,
#                 "lng": 6.869805
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 5,
#                 "usersCount": 3
#             },
#             "id": "56a25cdc498e0101a80be4d7",
#             "categories": [
#                 {
#                     "pluralName": "Hotels",
#                     "primary": true,
#                     "name": "Hotel",
#                     "shortName": "Hotel",
#                     "id": "4bf58dd8d48988d1fa931735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/hotel_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "La Beuratte",
#             "referralId": "v-1480504551",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 2761,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.970847399324015,
#                         "lng": 6.868017462366129,
#                         "label": "display"
#                     }
#                 ],
#                 "city": "Cornimont",
#                 "cc": "FR",
#                 "country": "France",
#                 "postalCode": "88310",
#                 "state": "Lotharingen",
#                 "formattedAddress": [
#                     "88310 Cornimont",
#                     "France"
#                 ],
#                 "lat": 47.970847399324015,
#                 "lng": 6.868017462366129
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 12,
#                 "usersCount": 2
#             },
#             "id": "57866678498e4dbfe65605b4",
#             "categories": [
#                 {
#                     "pluralName": "Bed & Breakfasts",
#                     "primary": true,
#                     "name": "Bed & Breakfast",
#                     "shortName": "B & B",
#                     "id": "4bf58dd8d48988d1f8931735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/bedandbreakfast_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Les Vallees Hotel La Bresse",
#             "referralId": "v-1480504551",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 3682,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 48.00793623344735,
#                         "lng": 6.881634813069359,
#                         "label": "display"
#                     }
#                 ],
#                 "city": "La Bresse",
#                 "cc": "FR",
#                 "country": "France",
#                 "state": "Lorraine",
#                 "formattedAddress": [
#                     "31 Rue Paul Claudel",
#                     "La Bresse",
#                     "France"
#                 ],
#                 "address": "31 Rue Paul Claudel",
#                 "lat": 48.00793623344735,
#                 "lng": 6.881634813069359
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 2,
#                 "checkinsCount": 188,
#                 "usersCount": 117
#             },
#             "id": "4bd79778304fce72abbd33ab",
#             "categories": [
#                 {
#                     "pluralName": "Resorts",
#                     "primary": true,
#                     "name": "Resort",
#                     "shortName": "Resort",
#                     "id": "4bf58dd8d48988d12f951735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/resort_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Camping Domaine Du Haut Des Bluches",
#             "referralId": "v-1480504551",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 5817,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.99944504073477,
#                         "lng": 6.918095132879379,
#                         "label": "display"
#                     }
#                 ],
#                 "city": "La Bresse",
#                 "cc": "FR",
#                 "country": "France",
#                 "state": "Lorraine",
#                 "formattedAddress": [
#                     "La Bresse",
#                     "France"
#                 ],
#                 "lat": 47.99944504073477,
#                 "lng": 6.918095132879379
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 90,
#                 "usersCount": 51
#             },
#             "id": "4dfb89f818386e743d988091",
#             "categories": [
#                 {
#                     "pluralName": "Campgrounds",
#                     "primary": true,
#                     "name": "Campground",
#                     "shortName": "Campground",
#                     "id": "4bf58dd8d48988d1e4941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/campground_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "H\u00f4tel du Lac des Corbeaux",
#             "referralId": "v-1480504551",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 4781,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 48.0038497536209,
#                         "lng": 6.901645660400391,
#                         "label": "display"
#                     }
#                 ],
#                 "city": "La Bresse",
#                 "cc": "FR",
#                 "country": "France",
#                 "state": "Lorraine",
#                 "formattedAddress": [
#                     "Rue de hohneck",
#                     "La bresse",
#                     "France"
#                 ],
#                 "address": "Rue de hohneck",
#                 "lat": 48.0038497536209,
#                 "lng": 6.901645660400391
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 2,
#                 "checkinsCount": 118,
#                 "usersCount": 66
#             },
#             "id": "4cb8a2134352a1cde14b87f5",
#             "categories": [
#                 {
#                     "pluralName": "Hotels",
#                     "primary": true,
#                     "name": "Hotel",
#                     "shortName": "Hotel",
#                     "id": "4bf58dd8d48988d1fa931735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/hotel_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Auberge De La Jonquille",
#             "referralId": "v-1480504551",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 6735,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 48.030598,
#                         "lng": 6.906546,
#                         "label": "display"
#                     }
#                 ],
#                 "city": "La Bresse",
#                 "cc": "FR",
#                 "country": "France",
#                 "state": "Lorraine",
#                 "formattedAddress": [
#                     "La Bresse",
#                     "France"
#                 ],
#                 "lat": 48.030598,
#                 "lng": 6.906546
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 6,
#                 "usersCount": 5
#             },
#             "id": "4e3c3a9cae6045423654986c",
#             "categories": [
#                 {
#                     "pluralName": "French Restaurants",
#                     "primary": true,
#                     "name": "French Restaurant",
#                     "shortName": "French",
#                     "id": "4bf58dd8d48988d10c941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/french_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "L'auberge du Montagnard",
#             "referralId": "v-1480504551",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 5341,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 48.025974,
#                         "lng": 6.886316,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "FR",
#                 "country": "France",
#                 "formattedAddress": [
#                     "France"
#                 ],
#                 "lat": 48.025974,
#                 "lng": 6.886316
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 1,
#                 "usersCount": 1
#             },
#             "id": "57678850498ede5f0a0dda60",
#             "categories": [
#                 {
#                     "pluralName": "Restaurants",
#                     "primary": true,
#                     "name": "Restaurant",
#                     "shortName": "Restaurant",
#                     "id": "4bf58dd8d48988d1c4941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Col de Grosse Pierre",
#             "referralId": "v-1480504551",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 5426,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 48.02622669195109,
#                         "lng": 6.887666593215194,
#                         "label": "display"
#                     }
#                 ],
#                 "city": "Bresse",
#                 "cc": "FR",
#                 "country": "France",
#                 "state": "frankrijk",
#                 "formattedAddress": [
#                     "Bresse",
#                     "France"
#                 ],
#                 "lat": 48.02622669195109,
#                 "lng": 6.887666593215194
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 29,
#                 "usersCount": 27
#             },
#             "id": "4db94bd54df0ded98bce4af8",
#             "categories": [
#                 {
#                     "pluralName": "Outdoors & Recreation",
#                     "primary": true,
#                     "name": "Outdoors & Recreation",
#                     "shortName": "Outdoors & Recreation",
#                     "id": "4d4b7105d754a06377d81259",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Les Vosges, La Bresse",
#             "referralId": "v-1480504551",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 1004,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.992804425649766,
#                         "lng": 6.8535212362785805,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "FR",
#                 "country": "France",
#                 "formattedAddress": [
#                     "France"
#                 ],
#                 "lat": 47.992804425649766,
#                 "lng": 6.8535212362785805
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 22,
#                 "usersCount": 12
#             },
#             "id": "544d87b4498eead34f15f75b",
#             "categories": []
#         },
#         {
#             "verified": false,
#             "name": "Refuge De La Croix Louis",
#             "referralId": "v-1480504551",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 4815,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.981592,
#                         "lng": 6.905603,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "FR",
#                 "country": "France",
#                 "formattedAddress": [
#                     "France"
#                 ],
#                 "lat": 47.981592,
#                 "lng": 6.905603
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 1,
#                 "usersCount": 1
#             },
#             "id": "4c345e3e3896e21ee660eb90",
#             "categories": [
#                 {
#                     "pluralName": "Trails",
#                     "primary": true,
#                     "name": "Trail",
#                     "shortName": "Trail",
#                     "id": "4bf58dd8d48988d159941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Moyenmont",
#             "referralId": "v-1480504551",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "distance": 2970,
#                 "labeledLatLngs": [
#                     {
#                         "lat": 48.00354478501516,
#                         "lng": 6.874564507254446,
#                         "label": "display"
#                     }
#                 ],
#                 "city": "La Bresse",
#                 "cc": "FR",
#                 "country": "France",
#                 "state": "Lorraine",
#                 "formattedAddress": [
#                     "La Bresse",
#                     "France"
#                 ],
#                 "lat": 48.00354478501516,
#                 "lng": 6.874564507254446
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 3,
#                 "usersCount": 1
#             },
#             "id": "4bb75e0346d4a593c25bc7c0",
#             "categories": []
#         }
#     ]
# }

# %% [markdown]
# Now that we can make some sense of the structure let's practice traversing the JSON hieararchy, select one of the venues in the list and output it's name

# %%
# Solution
from unicodedata import normalize
normalize('NFKC',la_bresse['venues'][0]['name'])
# Out:
# u'Bar Lounge La Grange'

# %% [markdown]
# Note that the output isn't exactly what we want. It says u'Park', and if you check the type, Python will output Unicode. This isn't good, we need to recover the original intended type. Read the following docs:
#
# https://docs.python.org/2/library/unicodedata.html, and checkup the method 'normalize'. Once you think you've understood this method. Implement it on the above call and see if you can recover the appropriate type for that data.

# %% [markdown]
# Now for some exploratory analysis, let's print the number of total venues in your list

# %%
# Solution
len(la_bresse['venues'])
# Out:
# 30

# %% [markdown]
# Extract the location id for your starting list. Make sure it's normalized to its correct type, and not Unicode. Put this id in a variable called temp. From this id, we will get a list of other venues.

# %%
# Solution
temp = la_bresse['venues'][0]['id']

# %% [markdown]
# Print the venues list (in the nicely formatted JSON)

# %%
# Solution

# %% [markdown]
# Create a procedure that will only extract the comments in a list. There are a few ways you can do this, but I highly recommend you look up the map method from the base Python library: https://docs.python.org/2/tutorial/datastructures.html
#
# This is the same "map" function, that's one part of the map-reduce duo used in "Big Data" applications. So it may be helpful to get familiar with this method now if that's where you think you may want to take your career in the future.

# %%
# Solution

# %% [markdown]
# Now we're going to bring the above mini-tasks together into a nice little method, that will allow us to convert any foursquare JSON data into a nice tabular / rectangular table for further analysis. First instnatiate a pandas data frame.

# %% [markdown]
# Write a procedure that will take your list of venues around a certain geography/lat/long whatever, and output a table that will have for each row, a comment associated for the venue (multiple comments will mean multiple rows, each per comment), the venue name, the tip count, the user count, and the store category. Make sure that each column is populated with appropriately typed values, i.e. names/categories should be strings, and numbers should be numerical data type.

# %% [markdown]
# > To the instructor: I usually don't have this much latitude to the student, but it was requested that I give some "open ended"/"munch on" problems. I suspect the students will spend the most time here, they will certainly get errors, and they will be frustrated. Look through the ideal solution and be prepared to step in when appropriate.
#
# **Hint**: Before you begin, think about the process. You're going to start with a loop of some kind, then think about the following:
# - How many of those do you need?
# - Think about the JSON structure, how "deep" do you need to penetrate the hierarchy to reach the data you want (this will help you think about how many loops you need for your crawler
# - How should you iteratively add on to your Pandas data frame?
# - Think of any tests you may need to put in to ensure your procedure does not cause an error (this may help you figure out how many if statements you may need, and where to place them.

# %%
# Solution - Note to instructor, the code may be slightly different, in particular the student should have written error-exception protocols to account for any 
# missing/empty values that may cause the procedure to kick-out in an error.

# %% [markdown]
# Finally, output the Venue table

# %% [markdown]
# You've done it! You've built a simple crawler that traverses a JSON directory, and you've deposited the results in a nice Pandas data frame. Congratulations! You're now ready for more data-mining in the future, and have just beefed up the **data** part of the data science combination :)
