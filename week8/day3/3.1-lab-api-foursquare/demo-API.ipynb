# %%
import foursquare
import pandas as pd

CLIENT_ID = 'Z4PSJN0G0Q44QX1SL0SSWI3EXA0KWG0POKGKHFY0J35EIIQE'
CLIENT_SECRET = 'EHRZQ4XSZKFEQIG03D1AS0BFFR3LE00GSBHOJUNOOKELUDHV'
client = foursquare.Foursquare(client_id=CLIENT_ID,client_secret=CLIENT_SECRET)

# %%
bounding_box = [6.8417737928,47.9883673828,6.9227220566,48.0355720646]

# %%
la_bresse = client.venues.search(params={'ll': ' 47.9883673828,6.8417737928'})

# %%
for x in la_bresse['venues']:
    print x['name']
# Out:
# Bar Lounge La Grange
# La Bresse
# Ferme des Vieux Sapins
# Les Chalets des Chatelminés
# Gîte Pima
# l'auberge du brabant
# Col Du Brabant
# Collet Mansuy
# Col d'Oderen
# Ventron
# Bol d'air
# Les Délices de la Bresse Pinot
# Lac des Corbeaux
# Super U
# office du tourisme la bresse
# Piquante Pierre
# Col De La Croix Des Moinats
# honneck
# Vosges en Marche
# Les Vallees Hotel La Bresse
# La Beuratte
# Camping Domaine Du Haut Des Bluches
# Le Den's
# Hôtel du Lac des Corbeaux
# L'auberge du Montagnard
# Auberge De La Jonquille
# Col de Grosse Pierre
# Les Vosges, La Bresse
# Refuge De La Croix Louis
# Moyenmont

# %%
print la_bresse['venues'][10]['id']
print la_bresse['venues'][10]['name']
# Out:
# 4b51036ff964a520953d27e3
# Bol d'air

# %%
client.venues('4b51036ff964a520953d27e3')['venue']
# Out:
# {u'attributes': {u'groups': [{u'count': 5,
#     u'items': [{u'displayName': u'Credit Cards', u'displayValue': u'Yes'}],
#     u'name': u'Credit Cards',
#     u'summary': u'Credit Cards',
#     u'type': u'payments'}]},
#  u'beenHere': {u'count': 0,
#   u'lastCheckinExpiredAt': 0,
#   u'marked': False,
#   u'unconfirmedCount': 0},
#  u'bestPhoto': {u'createdAt': 1469448829,
#   u'height': 1440,
#   u'id': u'5796027d498e351401e686a8',
#   u'prefix': u'https://irs2.4sqi.net/img/general/',
#   u'source': {u'name': u'Swarm for iOS', u'url': u'https://www.swarmapp.com'},
#   u'suffix': u'/180976340_QAytd8ZreXcQ6QrgVEpQmzvDUabBuf4ynqnTV5DCn1M.jpg',
#   u'visibility': u'public',
#   u'width': 1920},
#  u'canonicalUrl': u'https://foursquare.com/v/bol-dair/4b51036ff964a520953d27e3',
#  u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#     u'suffix': u'.png'},
#    u'id': u'5109983191d435c0d71c2bb1',
# ...
