# %% [markdown]
# # Decision Trees and Ensembles Lab
#
# In this lab we will compare the performance of a simple Decision Tree classifier with a Bagging classifier. We will do that on few datasets, starting from the ones offered by Scikit Learn. This lab will not include much starter code; hence we ease into doing things independently. Do ask if you are stuck though.

# %% [markdown]
# ## 1. Breast Cancer Dataset
# We will start our comparison on the breast cancer dataset.
# You can load it directly from scikit-learn using the `load_breast_cancer` function.
#
# ### 1.a Simple comparison
# 1. Load the data and create X and y
# - Initialise a Decision Tree Classifier and use cross_val_score to evaluate its performance. Set crossvalidation to 5-folds
# - Wrap a Bagging Classifier around the Decision Tree Classifier and use cross_val_score to evaluate its performance. Set crossvalidation to 5-folds.
# - Which score is better? Are the score significantly different? How can you judge that?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from __future__ import print_function

# %%
from sklearn.datasets import load_breast_cancer
X,y = load_breast_cancer(return_X_y=True)

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score

tree = DecisionTreeClassifier(random_state=1)
print("Trees Score:\t", cross_val_score(tree, X, y, cv=5).mean())
# Out:
# Trees Score:	 0.917491342824

# %%
from sklearn.ensemble import BaggingClassifier
bagging=BaggingClassifier(tree, n_estimators=100, random_state=42)
print("Bagging Score:\t", cross_val_score(bagging, X, y, cv=5).mean())
# Out:
# Bagging Score:	 0.965063485956

# %% [markdown]
# ### 1.b Scaled pipelines
# As you may have noticed the features are not normalised. Do the score improve with normalisation?
# For further experience with pipelines and scaling:
#
# 1. Create 2 pipelines, with a scaling preprocessing step and then either a decision tree or a bagging decision tree.
# - Which score is better? Are the score significantly different? How can you judge that?
# - Are the scores different from the non-scaled data?

# %%
from sklearn import preprocessing
norm = preprocessing.Normalizer()

from sklearn.pipeline import Pipeline
pipe1 = Pipeline([('norm',norm),('tree',tree)])
pipe2 = Pipeline([('norm',norm),('bagging',bagging)])

print(cross_val_score(pipe1, X, y, cv=5).mean())
print(cross_val_score(pipe2, X, y, cv=5).mean())
# Out:
# 0.919199692189
# 0.956183147364

# %% [markdown]
# ### 1.c Grid Search
#
# Grid search is a great way to improve the performance of a classifier. Let's explore the parameter space of both models and see if we can improve their performance.
#
# 1. Initialize a GridSearchCV with 5-fold cross validation for the Decision Tree Classifier
# - search for few values of the parameters in order to improve the score of the classifier
# - Use the whole X, y dataset for your test
# - Check the best\_score\_ once you've trained it. Is it better than before?
# - How does the score of the Grid-searched DT compare with the score of the Bagging DT?
# - Initialize a GridSearchCV with 5-fold cross validation for the Bagging Decision Tree Classifier
# - Repeat the search
#     - Note that you'll have to change parameter names for the base_estimator
#     - Note that there are also additional parameters to change
#     - Note that you may end up with a grid space to large to search in a short time
#     - Make use of the n_jobs parameter to speed up your grid search
# - Does the score improve for the Grid-searched Bagging Classifier?
# - Which score is better? Are the score significantly different? How can you judge that?

# %%
from sklearn.model_selection import GridSearchCV
params = {
    'max_depth':range(1,5),
    'min_samples_split':range(2,5),
    'min_samples_leaf':range(1,5)
}
grid = GridSearchCV(tree,params,cv=5).fit(X,y)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'min_samples_split': 2, 'max_depth': 2, 'min_samples_leaf': 1}
# 0.927943760984

# %%
from sklearn.model_selection import GridSearchCV
params = {
    'base_estimator__max_depth':range(1,5),
    'base_estimator__min_samples_split':range(2,5),
    'base_estimator__min_samples_leaf':range(1,5)
}
grid = GridSearchCV(bagging,param_grid = params,cv=5,n_jobs=-1).fit(X,y)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'base_estimator__min_samples_split': 4, 'base_estimator__max_depth': 4, 'base_estimator__min_samples_leaf': 1}
# 0.959578207381

# %% [markdown]
# ## 2 Diabetes and Regression
#
# Sklearn has a dataset of diabetic patients obtained from this study:
#
# http://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
# http://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf
#
# 442 diabetes patients were measured on 10 baseline variables: age, sex, body mass index, average blood pressure, and six blood serum measurements.
#
# The target is a quantitative measure of disease progression one year after baseline.
#
# Repeat the above comparison between a DecisionTreeRegressor and a Bagging version of the same.

# %% [markdown]
# ### 2.a Simple comparison
# 1. Load the data and create X and y
# - Initialize a Decision Tree Regressor and use cross_val_score to evaluate it's performance. Set crossvalidation to 5-folds. Which score will you use?
# - Wrap a Bagging Regressor around the Decision Tree Regressor and use cross_val_score to evaluate it's performance. Set crossvalidation to 5-folds.
# - Which score is better? Are the score significantly different? How can you judge that?

# %%
from sklearn.datasets import load_diabetes
X,y = load_diabetes(return_X_y=True)

from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score

tree = DecisionTreeRegressor(random_state=1)
print("Trees Score:\t", cross_val_score(tree, X, y, cv=5).mean())
# Out:
# Trees Score:	 -0.140462749211

# %%
from sklearn.ensemble import BaggingRegressor
bagging=BaggingRegressor(tree, n_estimators=100, random_state=42)
print("Bagging Score:\t", cross_val_score(bagging, X, y, cv=5).mean())
# Out:
# Bagging Score:	 0.418741681617

# %% [markdown]
# ### 2.b Grid Search
#
# Repeat Grid search as above:
#
# 1. Initialize a GridSearchCV with 5-fold cross validation for the Decision Tree Regressor
# - Search for few values of the parameters in order to improve the score of the regressor
# - Use the whole X, y dataset for your test
# - Check the best\_score\_ once you've trained it. Is it better than before?
# - How does the score of the Grid-searched DT compare with the score of the Bagging DT?
# - Initialize a GridSearchCV with 5-fold cross validation for the Bagging Decision Tree Regressor
# - Repeat the search
#     - Note that you'll have to change parameter names for the base_estimator
#     - Note that there are also additional parameters to change
#     - Note that you may end up with a grid space to large to search in a short time
#     - Make use of the n_jobs parameter to speed up your grid search
# - Does the score improve for the Grid-searched Bagging Regressor?
# - Which score is better? Are the score significantly different? How can you judge that?

# %%
params = {
    'max_depth':range(1,5),
    'min_samples_split':range(2,5),
    'min_samples_leaf':range(1,5)
}
grid = GridSearchCV(tree,params,cv=5,n_jobs=-1).fit(X,y)
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'min_samples_split': 2, 'max_depth': 3, 'min_samples_leaf': 4}
# 0.337383150805

# %%
params = {
    'base_estimator__max_depth':range(1,5),
    'base_estimator__min_samples_split':range(2,5),
    'base_estimator__min_samples_leaf':range(1,5)
}

import cProfile
cProfile.run('grid = GridSearchCV(bagging,param_grid = params,cv=5,n_jobs=-1).fit(X,y)')
print(grid.best_params_)
print(grid.best_score_)
# Out:
#          373863 function calls (370404 primitive calls) in 11.698 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   11.715   11.715 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <string>:1(FullArgSpec)
#         1    0.000    0.000    0.000    0.000 <string>:8(__new__)
#        16    0.000    0.000    0.001    0.000 Queue.py:107(put)
#         1    0.000    0.000    0.000    0.000 Queue.py:197(_init)
#        16    0.000    0.000    0.000    0.000 Queue.py:204(_put)
#         1    0.000    0.000    0.000    0.000 Queue.py:26(__init__)
#         2    0.000    0.000    0.002    0.001 __init__.py:102(Pipe)
#         1    0.000    0.000    0.000    0.000 __init__.py:109(cpu_count)
#         2    0.000    0.000    0.000    0.000 __init__.py:171(Lock)
#         1    0.000    0.000    0.000    0.000 __init__.py:375(_get_n_jobs)
#      2866    0.020    0.000    0.063    0.000 _abcoll.py:548(update)
#       100    0.000    0.000    0.000    0.000 _methods.py:25(_amax)
#       206    0.000    0.000    0.001    0.000 _methods.py:31(_sum)
#         2    0.000    0.000    0.000    0.000 _methods.py:37(_any)
#         6    0.000    0.000    0.000    0.000 _methods.py:43(_count_reduce_items)
#         6    0.000    0.000    0.000    0.000 _methods.py:53(_mean)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:101(effective_n_jobs)
#         1    0.000    0.000    0.240    0.240 _parallel_backends.py:107(apply_async)
#         2    0.000    0.000    0.000    0.000 _parallel_backends.py:118(effective_n_jobs)
#         1    0.000    0.000    0.134    0.134 _parallel_backends.py:130(terminate)
#        16    0.000    0.000    0.002    0.000 _parallel_backends.py:137(apply_async)
#        17    0.000    0.000    0.000    0.000 _parallel_backends.py:166(compute_batch_size)
#         2    0.000    0.000    0.000    0.000 _parallel_backends.py:262(effective_n_jobs)
#         2    0.000    0.000    0.095    0.047 _parallel_backends.py:286(configure)
#         1    0.000    0.000    0.134    0.134 _parallel_backends.py:311(terminate)
#         1    0.000    0.000    0.240    0.240 _parallel_backends.py:319(__init__)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:324(get)
#        16    0.000    0.000    0.000    0.000 _parallel_backends.py:335(__init__)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:355(__init__)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:46(configure)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:55(terminate)
#         2    0.000    0.000    0.000    0.000 _parallel_backends.py:58(compute_batch_size)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:62(batch_completed)
#         1    0.000    0.000    0.000    0.000 _search.py:328(_check_param_grid)
#         1    0.000    0.000    0.000    0.000 _search.py:375(__init__)
#         1    0.001    0.001   11.715   11.715 _search.py:534(_fit)
#        16    0.001    0.000    0.095    0.006 _search.py:555(<genexpr>)
#         4    0.000    0.000    0.001    0.000 _search.py:578(_store)
#         1    0.000    0.000    0.000    0.000 _search.py:87(__init__)
#         1    0.000    0.000    0.000    0.000 _search.py:910(__init__)
#         1    0.000    0.000   11.715   11.715 _search.py:922(fit)
#         4    0.000    0.000    0.000    0.000 _search.py:94(__iter__)
#         1    0.000    0.000    0.000    0.000 _split.py:1519(check_cv)
#         1    0.000    0.000    0.000    0.000 _split.py:267(__init__)
#        19    0.000    0.000    0.003    0.000 _split.py:289(split)
#         1    0.000    0.000    0.000    0.000 _split.py:324(get_n_splits)
#         1    0.000    0.000    0.000    0.000 _split.py:402(__init__)
#        19    0.000    0.000    0.000    0.000 _split.py:406(_iter_test_indices)
#        19    0.000    0.000    0.002    0.000 _split.py:64(split)
#        19    0.000    0.000    0.001    0.000 _split.py:97(_iter_test_masks)
#      8653    0.004    0.000    0.004    0.000 _weakrefset.py:70(__contains__)
#      3097    0.005    0.000    0.008    0.000 abc.py:128(__instancecheck__)
#      2866    0.002    0.000    0.004    0.000 abc.py:148(__subclasscheck__)
#        10    0.001    0.000    0.001    0.000 arraysetops.py:96(unique)
#         1    0.000    0.000    0.000    0.000 atexit.py:37(register)
#        18    0.000    0.000    0.000    0.000 bagging.py:197(__init__)
#         1    0.000    0.000    0.241    0.241 bagging.py:224(fit)
#         1    0.000    0.000    0.241    0.241 bagging.py:250(_fit)
#         2    0.000    0.000    0.000    0.000 bagging.py:364(<genexpr>)
#       200    0.000    0.000    0.002    0.000 bagging.py:37(_generate_indices)
#         2    0.000    0.000    0.000    0.000 bagging.py:377(<genexpr>)
#         2    0.000    0.000    0.000    0.000 bagging.py:379(<genexpr>)
#         1    0.000    0.000    0.000    0.000 bagging.py:390(_validate_y)
#       100    0.000    0.000    0.003    0.000 bagging.py:49(_generate_bagging_indices)
#         1    0.004    0.004    0.240    0.240 bagging.py:65(_parallel_build_estimators)
#        18    0.000    0.000    0.000    0.000 bagging.py:903(__init__)
#         1    0.000    0.000    0.000    0.000 bagging.py:965(_validate_estimator)
#       100    0.001    0.000    0.164    0.002 base.py:108(_make_estimator)
#       100    0.000    0.000    0.000    0.000 base.py:115(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base.py:139(_partition_estimators)
#       100    0.001    0.000    0.080    0.001 base.py:18(_set_random_states)
#       477    0.011    0.000    0.200    0.000 base.py:193(_get_param_names)
#   477/476    0.021    0.000    0.246    0.001 base.py:220(get_params)
#        12    0.000    0.000    0.000    0.000 base.py:253(<genexpr>)
#   204/201    0.000    0.000    0.043    0.000 base.py:257(set_params)
#  1614/118    0.005    0.000    0.181    0.002 base.py:37(clone)
#         1    0.000    0.000    0.000    0.000 base.py:526(is_classifier)
#        18    0.000    0.000    0.000    0.000 base.py:81(__init__)
#       528    0.000    0.000    0.000    0.000 base.py:887(isspmatrix)
#         1    0.000    0.000    0.000    0.000 base.py:93(_validate_estimator)
#      1432    0.007    0.000    0.012    0.000 collections.py:121(values)
#      1910    0.010    0.000    0.014    0.000 collections.py:125(items)
#       241    0.160    0.001    0.210    0.001 collections.py:305(namedtuple)
#     18798    0.010    0.000    0.012    0.000 collections.py:349(<genexpr>)
#      1928    0.001    0.000    0.003    0.000 collections.py:373(<genexpr>)
#      1928    0.002    0.000    0.005    0.000 collections.py:375(<genexpr>)
#      2866    0.014    0.000    0.082    0.000 collections.py:50(__init__)
#     34366    0.035    0.000    0.035    0.000 collections.py:71(__setitem__)
#     43427    0.009    0.000    0.009    0.000 collections.py:90(__iter__)
#         2    0.000    0.000    0.002    0.001 connection.py:205(Pipe)
#         2    0.000    0.000    0.000    0.000 connection.py:83(arbitrary_address)
#      1478    0.004    0.000    0.007    0.000 copy.py:145(deepcopy)
#      1478    0.000    0.000    0.000    0.000 copy.py:198(_deepcopy_atomic)
#      1478    0.002    0.000    0.003    0.000 copy.py:267(_keep_alive)
#         3    0.000    0.000    0.000    0.000 core.py:1242(_recursive_make_descr)
#         3    0.000    0.000    0.000    0.000 core.py:1263(make_mask_descr)
#         3    0.000    0.000    0.000    0.000 core.py:2707(__new__)
#         3    0.000    0.000    0.000    0.000 core.py:2841(_update_from)
#         3    0.000    0.000    0.000    0.000 core.py:2867(__array_finalize__)
#       144    0.001    0.000    0.001    0.000 core.py:3179(__setitem__)
#        21    0.000    0.000    0.000    0.000 core.py:3267(__setattr__)
#       144    0.000    0.000    0.000    0.000 core.py:3435(unshare_mask)
#       144    0.000    0.000    0.000    0.000 core.py:3487(_get_data)
#         2    0.000    0.000    0.000    0.000 disk.py:34(memstr_to_bytes)
#         3    0.000    0.000    0.000    0.000 extras.py:105(masked_all)
#        16    0.000    0.000    0.014    0.001 forking.py:198(dump)
#        56    0.000    0.000    0.000    0.000 forking.py:230(duplicate)
#         8    0.000    0.000    0.050    0.006 forking.py:249(__init__)
#        48    0.000    0.000    0.000    0.000 forking.py:259(<genexpr>)
#        80    0.000    0.000    0.000    0.000 forking.py:282(thread_is_spawning)
#        48    0.000    0.000    0.000    0.000 forking.py:286(duplicate_for_child)
#        56    0.000    0.000    0.056    0.001 forking.py:290(wait)
#        52    0.000    0.000    0.001    0.000 forking.py:306(poll)
#         8    0.000    0.000    0.002    0.000 forking.py:309(terminate)
#         8    0.000    0.000    0.000    0.000 forking.py:341(get_command_line)
#         8    0.000    0.000    0.001    0.000 forking.py:390(get_preparation_data)
#        32    0.000    0.000    0.000    0.000 forking.py:424(reduce_connection)
#        32    0.000    0.000    0.000    0.000 forking.py:48(assert_spawning)
#        32    0.000    0.000    0.002    0.000 forking.py:65(dispatcher)
#       100    0.000    0.000    0.000    0.000 fromnumeric.py:128(reshape)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:1383(ravel)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:1490(nonzero)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1574(shape)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2047(cumsum)
#       100    0.000    0.000    0.001    0.000 fromnumeric.py:2180(amax)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:829(argsort)
#       241    0.006    0.000    0.222    0.001 func_inspect.py:160(getfullargspec)
#      6207    0.010    0.000    0.024    0.000 funcsigs.py:237(__init__)
#     22430    0.003    0.000    0.003    0.000 funcsigs.py:266(name)
#     16223    0.002    0.000    0.002    0.000 funcsigs.py:278(kind)
#       477    0.001    0.000    0.002    0.000 funcsigs.py:282(replace)
#       956    0.010    0.000    0.041    0.000 funcsigs.py:474(__init__)
#      6208    0.003    0.000    0.003    0.000 funcsigs.py:506(<genexpr>)
#       478    0.013    0.000    0.059    0.000 funcsigs.py:512(from_function)
#   956/478    0.010    0.000    0.163    0.000 funcsigs.py:55(signature)
#      1910    0.008    0.000    0.082    0.000 funcsigs.py:585(parameters)
#       478    0.001    0.000    0.020    0.000 funcsigs.py:596(replace)
#         8    0.000    0.000    0.000    0.000 function_base.py:857(average)
#        17    0.000    0.000    0.000    0.000 functools.py:17(update_wrapper)
#        17    0.000    0.000    0.000    0.000 functools.py:39(wraps)
#         2    0.000    0.000    0.000    0.000 genericpath.py:23(exists)
#         2    0.000    0.000    0.000    0.000 index_tricks.py:231(_retval)
#         2    0.000    0.000    0.000    0.000 index_tricks.py:251(__getitem__)
#       241    0.000    0.000    0.000    0.000 inspect.py:142(isfunction)
#       241    0.000    0.000    0.000    0.000 inspect.py:209(iscode)
#       241    0.000    0.000    0.000    0.000 inspect.py:67(ismethod)
#       241    0.002    0.000    0.003    0.000 inspect.py:744(getargs)
#       241    0.002    0.000    0.006    0.000 inspect.py:804(getargspec)
#         2    0.000    0.000    0.000    0.000 logger.py:23(_squeeze_time)
#         2    0.000    0.000    0.000    0.000 logger.py:39(short_format_time)
#         1    0.000    0.000    0.000    0.000 ntpath.py:285(expanduser)
#         9    0.000    0.000    0.000    0.000 ntpath.py:415(normpath)
#         2    0.000    0.000    0.000    0.000 ntpath.py:43(normcase)
#         1    0.000    0.000    0.000    0.000 ntpath.py:483(abspath)
#         8    0.000    0.000    0.000    0.000 ntpath.py:56(isabs)
#         3    0.000    0.000    0.000    0.000 ntpath.py:63(join)
#        23    0.000    0.000    0.000    0.000 ntpath.py:96(splitdrive)
#       108    0.000    0.000    0.001    0.000 numeric.py:148(ones)
#        12    0.000    0.000    0.000    0.000 numeric.py:414(asarray)
#       422    0.000    0.000    0.001    0.000 numeric.py:484(asanyarray)
#         1    0.000    0.000    0.000    0.000 numeric.py:803(flatnonzero)
#         4    0.000    0.000    0.000    0.000 numerictypes.py:942(_can_coerce_all)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:964(find_common_type)
#         1    0.000    0.000    0.000    0.000 os.py:407(unsetenv)
#         1    0.000    0.000    0.000    0.000 os.py:421(__setitem__)
#         1    0.000    0.000    0.000    0.000 os.py:424(__getitem__)
#         1    0.000    0.000    0.000    0.000 os.py:432(__delitem__)
#         1    0.000    0.000    0.000    0.000 os.py:444(__contains__)
#         2    0.000    0.000    0.000    0.000 os.py:446(get)
#        19    0.000    0.000    0.095    0.005 parallel.py:126(__init__)
#         1    0.000    0.000    0.240    0.240 parallel.py:130(__call__)
#        53    0.000    0.000    0.000    0.000 parallel.py:133(__len__)
#        17    0.000    0.000    0.001    0.000 parallel.py:169(delayed)
#        17    0.000    0.000    0.000    0.000 parallel.py:185(delayed_function)
#        17    0.000    0.000    0.000    0.000 parallel.py:206(__init__)
#         1    0.000    0.000    0.000    0.000 parallel.py:211(__call__)
#         2    0.000    0.000    0.000    0.000 parallel.py:469(__init__)
#       3/2    0.000    0.000    0.095    0.047 parallel.py:536(_initialize_backend)
#         2    0.000    0.000    0.134    0.067 parallel.py:551(_terminate_backend)
#        17    0.000    0.000    0.242    0.014 parallel.py:555(_dispatch)
#         2    0.000    0.000    0.000    0.000 parallel.py:56(get_active_backend)
#        19    0.000    0.000    0.338    0.018 parallel.py:586(dispatch_one_batch)
#         2    0.000    0.000    0.000    0.000 parallel.py:611(_print)
#         1    0.000    0.000    0.000    0.000 parallel.py:624(print_progress)
#         2    0.028    0.014   11.134    5.567 parallel.py:667(retrieve)
#         2    0.000    0.000   11.701    5.850 parallel.py:721(__call__)
#        48    0.000    0.000    0.000    0.000 pickle.py:1274(encode_long)
#        17    0.000    0.000    0.000    0.000 pickle.py:173(__init__)
#        17    0.000    0.000    0.014    0.001 pickle.py:220(dump)
#       744    0.002    0.000    0.003    0.000 pickle.py:227(memoize)
#       744    0.000    0.000    0.001    0.000 pickle.py:250(put)
#       128    0.000    0.000    0.000    0.000 pickle.py:260(get)
#   1209/17    0.003    0.000    0.014    0.001 pickle.py:269(save)
#      1209    0.000    0.000    0.000    0.000 pickle.py:333(persistent_id)
#    104/16    0.001    0.000    0.011    0.001 pickle.py:345(save_reduce)
#        57    0.000    0.000    0.000    0.000 pickle.py:432(save_none)
#        96    0.000    0.000    0.000    0.000 pickle.py:436(save_bool)
#        72    0.000    0.000    0.000    0.000 pickle.py:443(save_int)
#        48    0.000    0.000    0.001    0.000 pickle.py:467(save_long)
#       384    0.001    0.000    0.002    0.000 pickle.py:486(save_string)
#    160/40    0.000    0.000    0.008    0.000 pickle.py:538(save_tuple)
#        16    0.000    0.000    0.002    0.000 pickle.py:597(save_list)
#        16    0.000    0.000    0.001    0.000 pickle.py:614(_batch_appends)
#     56/16    0.000    0.000    0.013    0.001 pickle.py:646(save_dict)
#     56/16    0.001    0.000    0.013    0.001 pickle.py:661(_batch_setitems)
#        88    0.000    0.000    0.001    0.000 pickle.py:736(save_global)
#         1    0.000    0.000    0.000    0.000 pickle.py:805(whichmodule)
#         1    0.000    0.000    0.058    0.058 pool.py:136(__init__)
#         2    0.000    0.000    0.000    0.000 pool.py:194(__init__)
#         1    0.000    0.000    0.051    0.051 pool.py:210(_repopulate_pool)
#         1    0.000    0.000    0.000    0.000 pool.py:287(__init__)
#        16    0.000    0.000    0.002    0.000 pool.py:289(apply_async)
#         2    0.000    0.000    0.000    0.000 pool.py:302(register)
#         2    0.000    0.000    0.002    0.001 pool.py:332(__init__)
#        16    0.000    0.000    0.000    0.000 pool.py:342(__getstate__)
#         2    0.000    0.000    0.000    0.000 pool.py:355(_make_methods)
#         1    0.000    0.000    0.000    0.000 pool.py:369(send)
#         1    0.000    0.000    0.058    0.058 pool.py:410(__init__)
#         1    0.000    0.000    0.002    0.002 pool.py:422(_setup_queues)
#         1    0.000    0.000    0.000    0.000 pool.py:432(delete_folder)
#         1    0.000    0.000    0.000    0.000 pool.py:455(close)
#         1    0.000    0.000    0.133    0.133 pool.py:461(terminate)
#         1    0.000    0.000    0.074    0.074 pool.py:476(_help_stuff_finish)
#         1    0.000    0.000    0.133    0.133 pool.py:485(_terminate_pool)
#         1    0.000    0.000    0.058    0.058 pool.py:513(__init__)
#        16    0.000    0.000    0.001    0.000 pool.py:537(__init__)
#       240    0.002    0.000   10.883    0.045 pool.py:552(wait)
#       240    0.001    0.000   10.883    0.045 pool.py:560(get)
#         1    0.000    0.000    0.134    0.134 pool.py:602(terminate)
#        16    0.000    0.000    0.000    0.000 process.py:107(<genexpr>)
#         8    0.000    0.000    0.050    0.006 process.py:116(start)
#         8    0.000    0.000    0.002    0.000 process.py:133(terminate)
#         4    0.000    0.000    0.056    0.014 process.py:139(join)
#         8    0.000    0.000    0.000    0.000 process.py:149(is_alive)
#         8    0.000    0.000    0.000    0.000 process.py:161(name)
#         8    0.000    0.000    0.000    0.000 process.py:165(name)
#         2    0.000    0.000    0.000    0.000 process.py:170(daemon)
#         8    0.000    0.000    0.000    0.000 process.py:177(daemon)
#         8    0.000    0.000    0.000    0.000 process.py:185(authkey)
#         8    0.000    0.000    0.000    0.000 process.py:196(exitcode)
#         4    0.000    0.000    0.000    0.000 process.py:205(ident)
#        16    0.000    0.000    0.000    0.000 process.py:286(__reduce__)
#        18    0.000    0.000    0.000    0.000 process.py:59(current_process)
#         8    0.000    0.000    0.000    0.000 process.py:76(_cleanup)
#         8    0.000    0.000    0.000    0.000 process.py:94(__init__)
#        12    0.000    0.000    0.000    0.000 random.py:273(choice)
#      5730    0.004    0.000    0.014    0.000 re.py:138(match)
#      5730    0.005    0.000    0.005    0.000 re.py:230(_compile)
#         1    0.000    0.000    0.000    0.000 scorer.py:222(check_scoring)
#       101    0.000    0.000    0.000    0.000 shape_base.py:61(atleast_2d)
#       100    0.000    0.000    0.000    0.000 shape_base.py:9(atleast_1d)
#       240    0.001    0.000    0.001    0.000 six.py:437(iteritems)
#         1    0.000    0.000    0.000    0.000 stats.py:5262(rankdata)
#         8    0.000    0.000    0.000    0.000 subprocess.py:487(_args_from_interpreter_flags)
#         2    0.000    0.000    0.000    0.000 synchronize.py:146(__init__)
#         2    0.000    0.000    0.000    0.000 synchronize.py:74(__init__)
#         2    0.000    0.000    0.000    0.000 synchronize.py:84(_make_methods)
#        16    0.000    0.000    0.000    0.000 synchronize.py:94(__getstate__)
#         2    0.000    0.000    0.000    0.000 tempfile.py:100(_exists)
#         2    0.000    0.000    0.000    0.000 tempfile.py:124(rng)
#         2    0.000    0.000    0.000    0.000 tempfile.py:135(next)
#         2    0.000    0.000    0.000    0.000 tempfile.py:221(_get_candidate_names)
#         1    0.000    0.000    0.000    0.000 tempfile.py:268(gettempdir)
#         2    0.000    0.000    0.000    0.000 tempfile.py:353(mktemp)
#         3    0.000    0.000    0.000    0.000 threading.py:1015(daemon)
#        11    0.000    0.000    0.000    0.000 threading.py:1143(currentThread)
#        25    0.000    0.000    0.001    0.000 threading.py:242(Condition)
#        25    0.001    0.000    0.001    0.000 threading.py:260(__init__)
#         3    0.000    0.000    0.000    0.000 threading.py:285(__enter__)
#         3    0.000    0.000    0.000    0.000 threading.py:288(__exit__)
#       194    0.000    0.000    0.000    0.000 threading.py:294(_release_save)
#       194    0.000    0.000    0.001    0.000 threading.py:297(_acquire_restore)
#       210    0.000    0.000    0.002    0.000 threading.py:300(_is_owned)
#       194    0.002    0.000   10.884    0.056 threading.py:309(wait)
#        16    0.000    0.000    0.000    0.000 threading.py:373(notify)
#         3    0.000    0.000    0.000    0.000 threading.py:542(Event)
#         3    0.000    0.000    0.000    0.000 threading.py:561(__init__)
#        11    0.000    0.000    0.000    0.000 threading.py:570(isSet)
#        31    0.000    0.000    0.000    0.000 threading.py:59(__init__)
#         3    0.000    0.000    0.004    0.001 threading.py:597(wait)
#         3    0.000    0.000    0.000    0.000 threading.py:620(_newname)
#       216    0.000    0.000    0.000    0.000 threading.py:64(_note)
#         3    0.000    0.000    0.000    0.000 threading.py:647(__init__)
#         3    0.000    0.000    0.000    0.000 threading.py:700(_set_daemon)
#         3    0.000    0.000    0.005    0.002 threading.py:717(start)
#         3    0.000    0.000    0.000    0.000 threading.py:902(join)
#         2    0.000    0.000    0.000    0.000 threading.py:958(name)
#         2    0.000    0.000    0.000    0.000 threading.py:986(isAlive)
#         3    0.000    0.000    0.000    0.000 threading.py:999(daemon)
#       100    0.003    0.000    0.067    0.001 tree.py:117(fit)
#       119    0.000    0.000    0.000    0.000 tree.py:82(__init__)
#       119    0.000    0.000    0.001    0.000 tree.py:944(__init__)
#         1    0.000    0.000    0.000    0.000 util.py:176(__init__)
#         1    0.000    0.000    0.133    0.133 util.py:192(__call__)
#         1    0.000    0.000    0.000    0.000 util.py:68(sub_debug)
#        24    0.000    0.000    0.000    0.000 util.py:72(debug)
#       249    0.000    0.000    0.001    0.000 validation.py:111(_num_samples)
#       201    0.000    0.000    0.001    0.000 validation.py:132(_shape_repr)
#       503    0.000    0.000    0.000    0.000 validation.py:159(<genexpr>)
#        10    0.000    0.000    0.001    0.000 validation.py:166(check_consistent_length)
#         9    0.000    0.000    0.002    0.000 validation.py:184(indexable)
#       201    0.001    0.000    0.007    0.000 validation.py:272(check_array)
#         1    0.000    0.000    0.000    0.000 validation.py:433(check_X_y)
#       202    0.001    0.000    0.002    0.000 validation.py:49(_assert_all_finite)
#         2    0.000    0.000    0.000    0.000 validation.py:536(column_or_1d)
#       401    0.001    0.000    0.002    0.000 validation.py:565(check_random_state)
#         1    0.000    0.000    0.001    0.001 validation.py:583(has_fit_parameter)
#      5247    0.003    0.000    0.003    0.000 warnings.py:340(__init__)
#      5247    0.009    0.000    0.009    0.000 warnings.py:361(__enter__)
#      5247    0.003    0.000    0.003    0.000 warnings.py:377(__exit__)
#      5247    0.005    0.000    0.006    0.000 warnings.py:96(simplefilter)
#         8    0.000    0.000    0.000    0.000 {CloseHandle}
#         2    0.000    0.000    0.000    0.000 {ConnectNamedPipe}
#         2    0.001    0.000    0.001    0.000 {CreateFile}
#         2    0.001    0.000    0.001    0.000 {CreateNamedPipe}
#         2    0.000    0.000    0.000    0.000 {SetNamedPipeHandleState}
#        88    0.000    0.000    0.000    0.000 {__import__}
#         8    0.000    0.000    0.000    0.000 {_struct.pack}
#         8    0.033    0.004    0.033    0.004 {_subprocess.CreateProcess}
#        56    0.000    0.000    0.000    0.000 {_subprocess.DuplicateHandle}
#        64    0.000    0.000    0.000    0.000 {_subprocess.GetCurrentProcess}
#         8    0.000    0.000    0.000    0.000 {_subprocess.GetExitCodeProcess}
#         8    0.002    0.000    0.002    0.000 {_subprocess.TerminateProcess}
#        48    0.056    0.001    0.056    0.001 {_subprocess.WaitForSingleObject}
#      1928    0.003    0.000    0.014    0.000 {all}
#        48    0.000    0.000    0.000    0.000 {binascii.unhexlify}
#         8    0.000    0.000    0.000    0.000 {built-in method Close}
#        56    0.000    0.000    0.000    0.000 {built-in method Detach}
#       723    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x000000001E2A1710}
#         2    0.000    0.000    0.000    0.000 {built-in method from_iterable}
#        17    0.000    0.000    0.000    0.000 {cPickle.dumps}
#       956    0.000    0.000    0.000    0.000 {callable}
#      1377    0.000    0.000    0.000    0.000 {chr}
#         1    0.000    0.000    0.000    0.000 {eval}
#         1    0.037    0.037    0.037    0.037 {gc.collect}
#     11704    0.004    0.000    0.004    0.000 {getattr}
#      7414    0.005    0.000    0.005    0.000 {hasattr}
#        48    0.000    0.000    0.000    0.000 {hex}
#      7332    0.001    0.000    0.001    0.000 {id}
#     13180    0.004    0.000    0.013    0.000 {isinstance}
#        78    0.000    0.000    0.000    0.000 {issubclass}
#       258    0.000    0.000    0.000    0.000 {iter}
#     15654    0.002    0.000    0.002    0.000 {len}
#       241    0.001    0.000    0.001    0.000 {map}
#       149    0.000    0.000    0.000    0.000 {max}
#      1928    0.001    0.000    0.001    0.000 {method '__contains__' of 'frozenset' objects}
#         3    0.000    0.000    0.000    0.000 {method '__enter__' of 'thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method '__exit__' of 'thread.lock' objects}
#        72    0.001    0.000    0.001    0.000 {method '__reduce_ex__' of 'object' objects}
#         1    0.074    0.074    0.074    0.074 {method 'acquire' of '_multiprocessing.SemLock' objects}
#      1053   10.882    0.010   10.882    0.010 {method 'acquire' of 'thread.lock' objects}
#      1695    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#        16    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#      6780    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#       100    0.055    0.001    0.055    0.001 {method 'build' of 'sklearn.tree._tree.DepthFirstTreeBuilder' objects}
#         8    0.000    0.000    0.000    0.000 {method 'close' of 'file' objects}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        12    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#      1096    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#       241    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        32    0.000    0.000    0.000    0.000 {method 'fileno' of '_multiprocessing.PipeConnection' objects}
#         4    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#      3615    0.009    0.000    0.009    0.000 {method 'format' of 'str' objects}
#     11857    0.002    0.000    0.002    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#         4    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#      5247    0.001    0.000    0.001    0.000 {method 'insert' of 'list' objects}
#     16870    0.001    0.000    0.001    0.000 {method 'isalnum' of 'str' objects}
#      1928    0.000    0.000    0.000    0.000 {method 'isdigit' of 'str' objects}
#      2926    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#       296    0.000    0.000    0.000    0.000 {method 'iteritems' of 'dict' objects}
#       710    0.003    0.000    0.011    0.000 {method 'join' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         9    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#      5730    0.005    0.000    0.005    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#         6    0.000    0.000    0.000    0.000 {method 'mean' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#      5488    0.001    0.000    0.001    0.000 {method 'pop' of 'list' objects}
#       201    0.002    0.000    0.002    0.000 {method 'randint' of 'mtrand.RandomState' objects}
#        12    0.000    0.000    0.000    0.000 {method 'random' of '_random.Random' objects}
#         4    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#       314    0.002    0.000    0.002    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       456    0.000    0.000    0.000    0.000 {method 'release' of 'thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#       522    0.001    0.000    0.001    0.000 {method 'replace' of 'str' objects}
#       104    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'send_bytes' of '_multiprocessing.PipeConnection' objects}
#        10    0.000    0.000    0.000    0.000 {method 'sort' of 'numpy.ndarray' objects}
#       356    0.001    0.000    0.001    0.000 {method 'split' of 'str' objects}
#      1755    0.001    0.000    0.001    0.000 {method 'startswith' of 'str' objects}
#       206    0.000    0.000    0.002    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'swapaxes' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'tolist' of 'numpy.ndarray' objects}
#        36    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'write' of '_io.BytesIO' objects}
#      2192    0.001    0.000    0.001    0.000 {method 'write' of 'file' objects}
#         1    0.000    0.000    0.000    0.000 {min}
#         8    0.000    0.000    0.000    0.000 {msvcrt.get_osfhandle}
#         1    0.000    0.000    0.000    0.000 {nt._getfullpathname}
#         8    0.000    0.000    0.000    0.000 {nt.close}
#         8    0.000    0.000    0.000    0.000 {nt.fdopen}
#        35    0.000    0.000    0.000    0.000 {nt.getpid}
#         2    0.000    0.000    0.000    0.000 {nt.lstat}
#         8    0.001    0.000    0.001    0.000 {nt.pipe}
#         2    0.000    0.000    0.000    0.000 {nt.putenv}
#         2    0.000    0.000    0.000    0.000 {nt.stat}
#         9    0.000    0.000    0.000    0.000 {numpy.core.multiarray.arange}
#       851    0.002    0.000    0.002    0.000 {numpy.core.multiarray.array}
#       100    0.000    0.000    0.000    0.000 {numpy.core.multiarray.bincount}
#        12    0.000    0.000    0.000    0.000 {numpy.core.multiarray.concatenate}
#       108    0.000    0.000    0.000    0.000 {numpy.core.multiarray.copyto}
#       112    0.000    0.000    0.000    0.000 {numpy.core.multiarray.empty}
#         2    0.000    0.000    0.000    0.000 {numpy.core.multiarray.result_type}
#        16    0.000    0.000    0.000    0.000 {numpy.core.multiarray.zeros}
#       249    0.000    0.000    0.000    0.000 {range}
#       241    0.001    0.000    0.001    0.000 {repr}
#       154    0.000    0.000    0.000    0.000 {setattr}
#       100    0.001    0.000    0.001    0.000 {sklearn.utils._random.sample_without_replacement}
#       578    0.002    0.000    0.002    0.000 {sorted}
#         1    0.000    0.000    0.000    0.000 {sum}
#       241    0.000    0.000    0.000    0.000 {sys._getframe}
#         3    0.000    0.000    0.000    0.000 {sys.getrefcount}
#       219    0.001    0.000    0.001    0.000 {thread.allocate_lock}
#        11    0.000    0.000    0.000    0.000 {thread.get_ident}
#         3    0.000    0.000    0.000    0.000 {thread.start_new_thread}
#        25    0.000    0.000    0.000    0.000 {time.time}
#         6    0.000    0.000    0.000    0.000 {zip}
#
#
# {'base_estimator__min_samples_split': 2, 'base_estimator__max_depth': 4, 'base_estimator__min_samples_leaf': 3}
# 0.437169522065

# %%
cProfile.run('grid = GridSearchCV(bagging,param_grid = params,cv=5,n_jobs=1).fit(X,y)')
print(grid.best_params_)
print(grid.best_score_)
# Out:
#          62538101 function calls (62162137 primitive calls) in 61.381 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <string>:1(FullArgSpec)
#         1    0.000    0.000    0.000    0.000 <string>:8(__new__)
#       721    0.000    0.000    0.000    0.000 __init__.py:375(_get_n_jobs)
#       960    0.002    0.000    0.007    0.000 __init__.py:83(safe_indexing)
#    592402    3.318    0.000   11.110    0.000 _abcoll.py:548(update)
#     24100    0.016    0.000    0.105    0.000 _methods.py:25(_amax)
#    100046    0.050    0.000    0.602    0.000 _methods.py:31(_sum)
#       962    0.000    0.000    0.003    0.000 _methods.py:37(_any)
#       486    0.001    0.000    0.001    0.000 _methods.py:43(_count_reduce_items)
#       486    0.005    0.000    0.008    0.000 _methods.py:53(_mean)
#       722    0.000    0.000    0.000    0.000 _parallel_backends.py:101(effective_n_jobs)
#   961/241    0.003    0.000   60.799    0.252 _parallel_backends.py:107(apply_async)
#       722    0.000    0.000    0.000    0.000 _parallel_backends.py:118(effective_n_jobs)
#       722    0.006    0.000    0.008    0.000 _parallel_backends.py:262(effective_n_jobs)
#       722    0.002    0.000    0.011    0.000 _parallel_backends.py:286(configure)
#   961/241    0.002    0.000   60.797    0.252 _parallel_backends.py:319(__init__)
#       961    0.000    0.000    0.000    0.000 _parallel_backends.py:324(get)
#       722    0.001    0.000    0.001    0.000 _parallel_backends.py:355(__init__)
#       722    0.001    0.000    0.001    0.000 _parallel_backends.py:46(configure)
#       722    0.000    0.000    0.000    0.000 _parallel_backends.py:55(terminate)
#      1683    0.000    0.000    0.000    0.000 _parallel_backends.py:58(compute_batch_size)
#       961    0.000    0.000    0.000    0.000 _parallel_backends.py:62(batch_completed)
#         1    0.000    0.000    0.000    0.000 _search.py:328(_check_param_grid)
#         1    0.000    0.000    0.000    0.000 _search.py:375(__init__)
#         1    0.000    0.000   61.418   61.418 _search.py:534(_fit)
#       241    0.002    0.000    0.456    0.002 _search.py:555(<genexpr>)
#         4    0.000    0.000    0.000    0.000 _search.py:578(_store)
#         1    0.000    0.000    0.000    0.000 _search.py:87(__init__)
#         1    0.000    0.000    0.000    0.000 _search.py:910(__init__)
#         1    0.000    0.000   61.419   61.419 _search.py:922(fit)
#        49    0.000    0.000    0.000    0.000 _search.py:94(__iter__)
#         1    0.000    0.000    0.000    0.000 _split.py:1519(check_cv)
#         1    0.000    0.000    0.000    0.000 _split.py:267(__init__)
#       288    0.001    0.000    0.010    0.000 _split.py:289(split)
#         1    0.000    0.000    0.000    0.000 _split.py:324(get_n_splits)
#         1    0.000    0.000    0.000    0.000 _split.py:402(__init__)
#       288    0.001    0.000    0.002    0.000 _split.py:406(_iter_test_indices)
#       288    0.002    0.000    0.008    0.000 _split.py:64(split)
#       288    0.001    0.000    0.004    0.000 _split.py:97(_iter_test_masks)
#       240    0.005    0.000   60.551    0.252 _validation.py:144(_fit_and_score)
#       480    0.002    0.000    3.169    0.007 _validation.py:282(_score)
#   1822269    0.751    0.000    0.751    0.000 _weakrefset.py:70(__contains__)
#    663497    0.986    0.000    1.559    0.000 abc.py:128(__instancecheck__)
#    592402    0.370    0.000    0.668    0.000 abc.py:148(__subclasscheck__)
#       818    0.008    0.000    0.018    0.000 arraysetops.py:96(unique)
#       480    0.001    0.000    2.646    0.006 bagging.py:183(_parallel_predict_regression)
#     48480    0.350    0.000    2.562    0.000 bagging.py:185(<genexpr>)
#       242    0.001    0.000    0.001    0.000 bagging.py:197(__init__)
#       241    0.002    0.000   57.060    0.237 bagging.py:224(fit)
#       241    0.014    0.000   57.058    0.237 bagging.py:250(_fit)
#       482    0.001    0.000    0.006    0.000 bagging.py:364(<genexpr>)
#     48200    0.041    0.000    0.593    0.000 bagging.py:37(_generate_indices)
#       482    0.000    0.000    0.000    0.000 bagging.py:377(<genexpr>)
#       482    0.000    0.000    0.000    0.000 bagging.py:379(<genexpr>)
#       241    0.000    0.000    0.001    0.000 bagging.py:390(_validate_y)
#     24100    0.048    0.000    0.787    0.000 bagging.py:49(_generate_bagging_indices)
#       241    1.162    0.005   56.791    0.236 bagging.py:65(_parallel_build_estimators)
#       242    0.001    0.000    0.002    0.000 bagging.py:903(__init__)
#       480    0.008    0.000    3.059    0.006 bagging.py:928(predict)
#       960    0.003    0.000    0.015    0.000 bagging.py:954(<genexpr>)
#       241    0.001    0.000    0.003    0.000 bagging.py:965(_validate_estimator)
#     24100    0.173    0.000   43.469    0.002 base.py:108(_make_estimator)
#     24100    0.008    0.000    0.008    0.000 base.py:115(<genexpr>)
#       721    0.009    0.000    0.017    0.000 base.py:139(_partition_estimators)
#     24100    0.202    0.000   20.900    0.001 base.py:18(_set_random_states)
#     98573    1.886    0.000   33.829    0.000 base.py:193(_get_param_names)
# 98573/98332    3.383    0.000   41.398    0.000 base.py:220(get_params)
#      2892    0.001    0.000    0.001    0.000 base.py:253(<genexpr>)
# 49164/48441    0.103    0.000   10.775    0.000 base.py:257(set_params)
#       480    0.006    0.000    3.162    0.007 base.py:357(score)
# 294766/24342    0.649    0.000   22.821    0.001 base.py:37(clone)
#         1    0.000    0.000    0.000    0.000 base.py:526(is_classifier)
#       242    0.000    0.000    0.000    0.000 base.py:81(__init__)
#    266472    0.089    0.000    0.161    0.000 base.py:887(isspmatrix)
#       241    0.000    0.000    0.000    0.000 base.py:93(_validate_estimator)
#    295960    1.101    0.000    1.600    0.000 collections.py:121(values)
#    394774    1.678    0.000    2.378    0.000 collections.py:125(items)
#       961    0.418    0.000    0.534    0.001 collections.py:305(namedtuple)
#     74958    0.017    0.000    0.020    0.000 collections.py:349(<genexpr>)
#      7688    0.003    0.000    0.006    0.000 collections.py:373(<genexpr>)
#      7688    0.004    0.000    0.013    0.000 collections.py:375(<genexpr>)
#    592402    2.241    0.000   14.065    0.000 collections.py:50(__init__)
#   7102558    6.279    0.000    6.279    0.000 collections.py:71(__setitem__)
#   8974963    1.200    0.000    1.200    0.000 collections.py:90(__iter__)
#    270182    0.554    0.000    1.058    0.000 copy.py:145(deepcopy)
#    270182    0.031    0.000    0.031    0.000 copy.py:198(_deepcopy_atomic)
#    270182    0.356    0.000    0.391    0.000 copy.py:267(_keep_alive)
#         3    0.000    0.000    0.000    0.000 core.py:1242(_recursive_make_descr)
#         3    0.000    0.000    0.000    0.000 core.py:1263(make_mask_descr)
#         3    0.000    0.000    0.000    0.000 core.py:2707(__new__)
#         3    0.000    0.000    0.000    0.000 core.py:2841(_update_from)
#         3    0.000    0.000    0.000    0.000 core.py:2867(__array_finalize__)
#       144    0.000    0.000    0.000    0.000 core.py:3179(__setitem__)
#        21    0.000    0.000    0.000    0.000 core.py:3267(__setattr__)
#       144    0.000    0.000    0.000    0.000 core.py:3435(unshare_mask)
#       144    0.000    0.000    0.000    0.000 core.py:3487(_get_data)
#       722    0.003    0.000    0.003    0.000 disk.py:34(memstr_to_bytes)
#         3    0.000    0.000    0.000    0.000 extras.py:105(masked_all)
#     24100    0.020    0.000    0.069    0.000 fromnumeric.py:128(reshape)
#       483    0.001    0.000    0.002    0.000 fromnumeric.py:1383(ravel)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:1490(nonzero)
#       482    0.000    0.000    0.000    0.000 fromnumeric.py:1574(shape)
#       480    0.001    0.000    0.004    0.000 fromnumeric.py:1892(any)
#       721    0.001    0.000    0.003    0.000 fromnumeric.py:2047(cumsum)
#     24100    0.042    0.000    0.147    0.000 fromnumeric.py:2180(amax)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:829(argsort)
#       961    0.017    0.000    0.579    0.001 func_inspect.py:160(getfullargspec)
#   1282895    1.742    0.000    4.132    0.000 funcsigs.py:237(__init__)
#   4635582    0.483    0.000    0.483    0.000 funcsigs.py:266(name)
#   3352687    0.332    0.000    0.332    0.000 funcsigs.py:278(kind)
#     98573    0.199    0.000    0.319    0.000 funcsigs.py:282(replace)
#    197628    1.833    0.000    7.466    0.000 funcsigs.py:474(__init__)
#   1283136    0.502    0.000    0.651    0.000 funcsigs.py:506(<genexpr>)
#     98814    2.212    0.000   10.756    0.000 funcsigs.py:512(from_function)
# 197628/98814    1.559    0.000   27.377    0.000 funcsigs.py:55(signature)
#    394774    1.341    0.000   13.410    0.000 funcsigs.py:585(parameters)
#     98814    0.155    0.000    3.548    0.000 funcsigs.py:596(replace)
#       968    0.007    0.000    0.022    0.000 function_base.py:857(average)
#       961    0.003    0.000    0.006    0.000 functools.py:17(update_wrapper)
#       961    0.002    0.000    0.002    0.000 functools.py:39(wraps)
#         2    0.000    0.000    0.000    0.000 index_tricks.py:231(_retval)
#         2    0.000    0.000    0.000    0.000 index_tricks.py:251(__getitem__)
#       961    0.001    0.000    0.001    0.000 inspect.py:142(isfunction)
#       961    0.000    0.000    0.001    0.000 inspect.py:209(iscode)
#       961    0.001    0.000    0.001    0.000 inspect.py:67(ismethod)
#       961    0.006    0.000    0.009    0.000 inspect.py:744(getargs)
#       961    0.005    0.000    0.016    0.000 inspect.py:804(getargspec)
#       722    0.001    0.000    0.002    0.000 logger.py:23(_squeeze_time)
#       722    0.002    0.000    0.005    0.000 logger.py:39(short_format_time)
#       480    0.003    0.000    0.011    0.000 metaestimators.py:83(_safe_split)
#     25352    0.039    0.000    0.154    0.000 numeric.py:148(ones)
#      1452    0.001    0.000    0.001    0.000 numeric.py:414(asarray)
#    197310    0.116    0.000    0.144    0.000 numeric.py:484(asanyarray)
#         1    0.000    0.000    0.000    0.000 numeric.py:803(flatnonzero)
#         4    0.000    0.000    0.000    0.000 numerictypes.py:942(_can_coerce_all)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:964(find_common_type)
#      1683    0.006    0.000    0.483    0.000 parallel.py:126(__init__)
#   961/241    0.004    0.000   60.797    0.252 parallel.py:130(__call__)
#      3605    0.001    0.000    0.001    0.000 parallel.py:133(__len__)
#       961    0.004    0.000    0.023    0.000 parallel.py:169(delayed)
#       961    0.000    0.000    0.000    0.000 parallel.py:185(delayed_function)
#       961    0.001    0.000    0.001    0.000 parallel.py:206(__init__)
#       961    0.005    0.000    0.007    0.000 parallel.py:211(__call__)
#       722    0.006    0.000    0.014    0.000 parallel.py:469(__init__)
#  1444/722    0.007    0.000    0.019    0.000 parallel.py:536(_initialize_backend)
#       722    0.001    0.000    0.001    0.000 parallel.py:551(_terminate_backend)
#   961/241    0.005    0.000   60.801    0.252 parallel.py:555(_dispatch)
#       722    0.001    0.000    0.003    0.000 parallel.py:56(get_active_backend)
#  1683/243    0.011    0.000   61.261    0.252 parallel.py:586(dispatch_one_batch)
#       722    0.000    0.000    0.000    0.000 parallel.py:611(_print)
#       961    0.001    0.000    0.001    0.000 parallel.py:624(print_progress)
#       722    0.009    0.000    0.590    0.001 parallel.py:667(retrieve)
#     722/2    0.040    0.000   61.411   30.706 parallel.py:721(__call__)
#       722    0.000    0.000    0.000    0.000 process.py:170(daemon)
#       722    0.000    0.000    0.000    0.000 process.py:59(current_process)
#   1184322    0.752    0.000    2.390    0.000 re.py:138(match)
#   1184322    0.715    0.000    0.715    0.000 re.py:230(_compile)
#       480    0.020    0.000    0.098    0.000 regression.py:370(r2_score)
#       480    0.003    0.000    0.047    0.000 regression.py:42(_check_reg_targets)
#       480    0.001    0.000    3.163    0.007 scorer.py:217(_passthrough_scorer)
#         1    0.000    0.000    0.000    0.000 scorer.py:222(check_scoring)
#     72821    0.168    0.000    0.263    0.000 shape_base.py:61(atleast_2d)
#     24100    0.044    0.000    0.071    0.000 shape_base.py:9(atleast_1d)
#     49648    0.063    0.000    0.093    0.000 six.py:437(iteritems)
#         1    0.000    0.000    0.000    0.000 stats.py:5262(rankdata)
#       722    0.001    0.000    0.001    0.000 threading.py:1143(currentThread)
#       722    0.001    0.000    0.001    0.000 threading.py:958(name)
#     24100    0.806    0.000   11.063    0.000 tree.py:117(fit)
#     48000    0.074    0.000    1.508    0.000 tree.py:385(_validate_X_predict)
#     48000    0.100    0.000    2.212    0.000 tree.py:407(predict)
#     24583    0.047    0.000    0.047    0.000 tree.py:82(__init__)
#     24583    0.061    0.000    0.108    0.000 tree.py:944(__init__)
#    100141    0.132    0.000    0.264    0.000 validation.py:111(_num_samples)
#     97881    0.159    0.000    0.496    0.000 validation.py:132(_shape_repr)
#    268583    0.114    0.000    0.114    0.000 validation.py:159(<genexpr>)
#       818    0.003    0.000    0.026    0.000 validation.py:166(check_consistent_length)
#        97    0.000    0.000    0.003    0.000 validation.py:184(indexable)
#     97881    0.657    0.000    3.278    0.000 validation.py:272(check_array)
#       241    0.001    0.000    0.024    0.000 validation.py:433(check_X_y)
#     98122    0.337    0.000    1.052    0.000 validation.py:49(_assert_all_finite)
#       482    0.001    0.000    0.003    0.000 validation.py:536(column_or_1d)
#     96641    0.327    0.000    0.696    0.000 validation.py:565(check_random_state)
#       241    0.001    0.000    0.058    0.000 validation.py:583(has_fit_parameter)
#       480    0.001    0.000    0.002    0.000 validation.py:651(check_is_fitted)
#   1084303    0.509    0.000    0.509    0.000 warnings.py:340(__init__)
#   1084303    1.153    0.000    1.153    0.000 warnings.py:361(__enter__)
#   1084303    0.610    0.000    0.610    0.000 warnings.py:377(__exit__)
#   1084303    0.828    0.000    1.116    0.000 warnings.py:96(simplefilter)
#      8168    0.008    0.000    0.028    0.000 {all}
#      2883    0.011    0.000    0.011    0.000 {built-in method __new__ of type object at 0x000000001E2A1710}
#       482    0.000    0.000    0.000    0.000 {built-in method from_iterable}
#       961    0.010    0.000    0.010    0.000 {cPickle.dumps}
#    197628    0.019    0.000    0.019    0.000 {callable}
#   2344732    0.640    0.000    0.640    0.000 {getattr}
#   1736988    0.976    0.000    0.976    0.000 {hasattr}
#    810546    0.056    0.000    0.056    0.000 {id}
#   2830123    0.704    0.000    2.262    0.000 {isinstance}
#       486    0.000    0.000    0.000    0.000 {issubclass}
#     50370    0.008    0.000    0.008    0.000 {iter}
#   3040366    0.216    0.000    0.217    0.000 {len}
#       961    0.002    0.000    0.002    0.000 {map}
#     25544    0.013    0.000    0.013    0.000 {max}
#      7688    0.002    0.000    0.002    0.000 {method '__contains__' of 'frozenset' objects}
#      6727    0.001    0.000    0.001    0.000 {method 'add' of 'set' objects}
#       480    0.001    0.000    0.002    0.000 {method 'any' of 'numpy.generic' objects}
#       482    0.001    0.000    0.002    0.000 {method 'any' of 'numpy.ndarray' objects}
#   1331185    0.185    0.000    0.185    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#     24100    7.541    0.000    7.558    0.000 {method 'build' of 'sklearn.tree._tree.DepthFirstTreeBuilder' objects}
#         3    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#       722    0.003    0.000    0.003    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#    241000    0.051    0.000    0.051    0.000 {method 'endswith' of 'str' objects}
#      1201    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#       818    0.001    0.000    0.001    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#     14415    0.026    0.000    0.026    0.000 {method 'format' of 'str' objects}
#   1824461    0.182    0.000    0.182    0.000 {method 'get' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#   1084303    0.201    0.000    0.201    0.000 {method 'insert' of 'list' objects}
#     67270    0.003    0.000    0.003    0.000 {method 'isalnum' of 'str' objects}
#      7688    0.001    0.000    0.001    0.000 {method 'isdigit' of 'str' objects}
#       480    0.001    0.000    0.001    0.000 {method 'item' of 'numpy.generic' objects}
#    592933    0.090    0.000    0.090    0.000 {method 'items' of 'dict' objects}
#     49648    0.013    0.000    0.013    0.000 {method 'iteritems' of 'dict' objects}
#     99803    0.215    0.000    0.348    0.000 {method 'join' of 'str' objects}
#   1184322    0.923    0.000    0.923    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#       486    0.001    0.000    0.008    0.000 {method 'mean' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#   1085264    0.198    0.000    0.198    0.000 {method 'pop' of 'list' objects}
#     48000    0.570    0.000    0.591    0.000 {method 'predict' of 'sklearn.tree._tree.Tree' objects}
#     48441    0.468    0.000    0.468    0.000 {method 'randint' of 'mtrand.RandomState' objects}
#       484    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#    125594    0.645    0.000    0.645    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      1922    0.002    0.000    0.002    0.000 {method 'replace' of 'str' objects}
#     25064    0.050    0.000    0.050    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       818    0.002    0.000    0.002    0.000 {method 'sort' of 'numpy.ndarray' objects}
#     26507    0.018    0.000    0.018    0.000 {method 'split' of 'str' objects}
#      7449    0.002    0.000    0.002    0.000 {method 'startswith' of 'str' objects}
#    100046    0.060    0.000    0.662    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'swapaxes' of 'numpy.ndarray' objects}
#       960    0.004    0.000    0.004    0.000 {method 'take' of 'numpy.ndarray' objects}
#      1442    0.001    0.000    0.001    0.000 {method 'tolist' of 'numpy.ndarray' objects}
#      1218    0.002    0.000    0.003    0.000 {method 'update' of 'dict' objects}
#       721    0.000    0.000    0.000    0.000 {min}
#        97    0.000    0.000    0.000    0.000 {numpy.core.multiarray.arange}
#    393579    0.473    0.000    0.473    0.000 {numpy.core.multiarray.array}
#     24100    0.095    0.000    0.095    0.000 {numpy.core.multiarray.bincount}
#       820    0.003    0.000    0.003    0.000 {numpy.core.multiarray.concatenate}
#     25352    0.086    0.000    0.086    0.000 {numpy.core.multiarray.copyto}
#     25356    0.030    0.000    0.030    0.000 {numpy.core.multiarray.empty}
#       482    0.000    0.000    0.000    0.000 {numpy.core.multiarray.result_type}
#       240    0.001    0.000    0.001    0.000 {numpy.core.multiarray.zeros}
#      1927    0.001    0.000    0.001    0.000 {range}
#       961    0.004    0.000    0.004    0.000 {repr}
#     27706    0.008    0.000    0.008    0.000 {setattr}
#     24100    0.185    0.000    0.287    0.000 {sklearn.utils._random.sample_without_replacement}
#    122674    0.292    0.000    0.292    0.000 {sorted}
#      1201    0.088    0.000    2.649    0.002 {sum}
#       961    0.001    0.000    0.001    0.000 {sys._getframe}
#         3    0.000    0.000    0.000    0.000 {sys.getrefcount}
#       722    0.002    0.000    0.002    0.000 {thread.allocate_lock}
#       722    0.000    0.000    0.000    0.000 {thread.get_ident}
#      4086    0.002    0.000    0.002    0.000 {time.time}
#        50    0.000    0.000    0.000    0.000 {zip}
#
#
# {'base_estimator__min_samples_split': 2, 'base_estimator__max_depth': 4, 'base_estimator__min_samples_leaf': 3}
# 0.437169522065

# %% [markdown]
# ## Bonus: Project 6 data
#
# Get a headstart on Project 6 by repeating this analysis on that dataset! You need to obtain it first though through the IMDB API.
